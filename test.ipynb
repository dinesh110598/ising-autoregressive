# %% [markdown]
# ## Testing notebook

# %%
import train
import ising, BPnet
import numpy as np
import tensorflow as tf
# Out:
# 2021-10-16 11:21:44.583622: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# 2021-10-16 11:22:04.788927: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-10-16 11:22:04.790236: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-10-16 11:22:04.872065: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-16 11:22:04.872848: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 2060 computeCapability: 7.5
# coreClock: 1.2GHz coreCount: 30 deviceMemorySize: 5.79GiB deviceMemoryBandwidth: 245.91GiB/s
# 2021-10-16 11:22:04.872892: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# ...

# %% [markdown]
# We'll try training the BPnet model with lattice size 64 and
# batch size 100, which happened to return a memory error in Flux.

# %%
model = BPnet.BPnet(18, 16, 2)
pars = ising.IsingParams(32)
train.train_loop(model, 100, 0.5, pars, batch_size=100, anneal=True, init_eta=0.01)
# Out:
# Training steps:   0%|          | 0/100 [00:00<?, ?it/s]
# WARNING:tensorflow:AutoGraph could not transform <bound method BPnet._sample_update of <tensorflow.python.eager.function.TfMethodTarget object at 0x7f4a0834a3a0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: invalid syntax (tmpl01alg2w.py, line 17)
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method BPnet._sample_update of <tensorflow.python.eager.function.TfMethodTarget object at 0x7f4a0834a3a0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: invalid syntax (tmpl01alg2w.py, line 17)
# ...

# %%
model = BPnet.BPnet(18,16,2)
x = model.sample(32, 100)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <bound method BPnet._sample_update of <tensorflow.python.eager.function.TfMethodTarget object at 0x7f2ca02aba30>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: invalid syntax (tmpb9pu0z_5.py, line 17)
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method BPnet._sample_update of <tensorflow.python.eager.function.TfMethodTarget object at 0x7f2ca02aba30>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: invalid syntax (tmpb9pu0z_5.py, line 17)
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ...
