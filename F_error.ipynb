# %% [markdown]
# # Simple PixelCNN

# %%
from SimplePCNN import SimplePCNN
import train
import ising
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from scipy import integrate
import math

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
model = SimplePCNN(L=24, net_depth=3, net_width=16, kernel_size=5)
ising.J = -1. #Ferromag coupling in Ising model
trainer = train.Trainer(model, batch_size=50, learning_rate=0.001)
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.0
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.3
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.0.l_cropping
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.0.l_padding
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.0.l_conv
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.0.l_conv2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.0.r_cropping
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.0.r_padding
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.0.r_conv
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.0.r_conv2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.0.m_conv
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.0.m_conv2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.1.l_cropping
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.1.l_padding
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.1.l_conv
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.1.l_conv2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.1.r_cropping
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.1.r_padding
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.1.r_conv
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.1.r_conv2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.1.m_conv
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.1.m_conv2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.1.m_res_conv
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.2.l_cropping
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.2.l_padding
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.2.l_conv
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.2.l_conv2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.2.r_cropping
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.2.r_padding
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.2.r_conv
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.2.r_conv2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.2.m_conv
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.2.m_conv2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.2.m_res_conv
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.0.l_conv.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.0.l_conv.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.0.l_conv2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.0.l_conv2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.0.r_conv.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.0.r_conv.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.0.r_conv2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.0.r_conv2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.0.m_conv.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.0.m_conv.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.0.m_conv2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.0.m_conv2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.1.l_conv.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.1.l_conv.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.1.l_conv2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.1.l_conv2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.1.r_conv.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.1.r_conv.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.1.r_conv2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.1.r_conv2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.1.m_conv.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.1.m_conv.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.1.m_conv2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.1.m_conv2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.1.m_res_conv.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.2.l_conv.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.2.l_conv.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.2.r_conv.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.2.r_conv.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.2.m_conv.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.2.m_conv.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.2.m_conv2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.2.m_conv2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).custom_layers.2.m_res_conv.kernel
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.

# %%
model.net.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masked_conv2d (MaskedConv2D) (None, 24, 24, 16)        416
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 24, 24, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 16)        272
# _________________________________________________________________
# res_block (ResBlock)         (None, 24, 24, 16)        6688
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 24, 24, 1)         17
# =================================================================
# Total params: 7,393
# Trainable params: 7,393
# Non-trainable params: 0
# _________________________________________________________________

# %%
beta = 0.5
history = trainer.train_loop(iter=2500, beta=beta, anneal=True)
#Set anneal=False if you are running this cell second 
#time to train this model further
# Out:
#   0%|          | 0/2500 [00:00<?, ?it/s]WARNING:tensorflow:AutoGraph could not transform <bound method AutoregressiveModel.graph_sampler of <SimplePCNN.SimplePCNN object at 0x7f02d81749a0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method AutoregressiveModel.graph_sampler of <SimplePCNN.SimplePCNN object at 0x7f02d81749a0>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function energy at 0x7f03b453c670> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function energy at 0x7f03b453c670> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 100%|██████████| 2500/2500 [18:15<00:00,  2.28it/s]

# %%
trainer.model.save_weights('SimplePCNNwts/b_'+str(beta))

# %%
beta = 0.55
model.load_weights('SimplePCNNwts/b_'+str(beta))

# %%
sample = model.sample(200)

# %%
np.abs(np.mean(sample, axis=(1,2,3))).mean()
# Out:
# 0.9081597222222223

# %%
beta = 0.55
history = trainer.train_loop(iter=2500, beta=beta, anneal=True)
# Out:
#   0%|          | 0/2500 [00:00<?, ?it/s]WARNING:tensorflow:AutoGraph could not transform <bound method AutoregressiveModel.graph_sampler of <SimplePCNN.SimplePCNN object at 0x7f9af51a9c10>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method AutoregressiveModel.graph_sampler of <SimplePCNN.SimplePCNN object at 0x7f9af51a9c10>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function energy at 0x7f9af713c040> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function energy at 0x7f9af713c040> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 100%|██████████| 2500/2500 [37:48<00:00,  1.10it/s]

# %%
trainer.model.save_weights('SimplePCNNwts/b_'+str(beta))

# %% [markdown]
# # Boltzmann PixelCNN

# %%
from BPnet import BPnet
import train
import ising
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from scipy import integrate
import math

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
model = BPnet(L=32, net_depth=3, net_width=16, kernel_size=5)
model.load_weights('BPnetwts/b_0.475')
ising.J = -1. #Ferromag coupling in Ising model
trainer = train.Trainer(model, batch_size=50, learning_rate=0.005)

# %%
trainer.lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(0.005, 250, 0.8, True)

# %%
0.8**16
# Out:
# 0.028147497671065624

# %%
beta = 0.475
history = trainer.train_loop(iter=4000, beta=beta, anneal=False)
#Set anneal=False if you are running this cell second 
#time to train this model further
trainer.model.save_weights("BPnetwts/b_"+str(beta))
# Out:
# 100%|██████████| 4000/4000 [1:34:09<00:00,  1.41s/it]

# %% [markdown]
# # Free energy evaluation

# %%
from BPnet import BPnet, CondBPnet
from SimplePCNN import SimplePCNN
import train
import ising
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from scipy import integrate
import math

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
#The function to evaluate integral of
def func(theta, beta):
    t1 = math.cosh(2*beta)**2
    k = 1./(math.sinh(2*beta)**2)
    t2 = (1./k)*math.sqrt(1 + k**2 - 2*k*math.cos(2*theta))
    return math.log(t1 + t2)

def integrator(beta):
    result = np.empty(beta.shape, float)
    for i in range(beta.shape[0]):
        val = beta[i]
        integrand = lambda theta: func(theta, val)
        result[i] = integrate.quad(integrand, 0 , math.pi)[0]
    return result

# %% [markdown]
# ### a) SimplePCNN

# %%
from SimplePCNN import SimplePCNN

# %%
model = SimplePCNN(L=36, net_depth=3, net_width=16, kernel_size=5)
betas = [0.35,0.4,0.425,0.45,
        0.475,0.5,0.55]
sample = []
log_prob = []
energy = []
free_energy = []

for beta in betas:
    model.load_weights('SimplePCNNwts/b_'+str(beta))
    sample.append(model.sample(200))
    log_prob.append(model.log_prob(sample[-1]))
    energy.append(ising.energy(sample[-1], pbc=True))
    free_energy.append(np.mean(((log_prob[-1]/beta)+energy[-1])/(model.L**2)))

# %%
beta = np.arange(0.3, 0.60001, 0.0125)
integral = integrator(beta)
F = -np.reciprocal(beta)*(math.log(2)/2 + integral*(1./(2*math.pi)))

# %%
betas = np.asarray(betas)
integral = integrator(betas)
F = -np.reciprocal(betas)*(math.log(2)/2 + integral*(1./(2*math.pi)))
free_energy_arr = np.asarray(free_energy)
error2 = (free_energy_arr-F)

# %%
plt.plot(beta, F, color='blue', label='Exact solution')
plt.scatter(betas, free_energy, color='red', label='Simple PCNN values')
plt.xlabel('Beta')
plt.ylabel('Free energy per particle')
plt.grid()
plt.legend()
plt.savefig('SimplePCNN_free_ener.png')
plt.show()

# %%
plt.plot(betas, error, color='blue', label='L=24')
plt.plot(betas, error2, color='green', label='L=36')
plt.plot(betas, error3, color='yellow', label='L=48')
plt.title('SimplePCNN')
plt.xlabel('Beta')
plt.ylabel('Error in F')
plt.grid()
plt.legend()
plt.savefig('F_DiffL_SimplePCNN.png')
plt.show()

# %% [markdown]
# ### a) BPnet

# %%
model = CondBPnet(L=72, net_depth=3, net_width=16, kernel_size=5)
model.load_weights('CondBPnet_wts/L36_D3')
betas = np.arange(0.4, 0.5001, 0.01)
samples = []
log_prob = []
energy = []
free_energy = []

for beta in betas:
    samples.append(model.sample(200, beta))
    log_prob.append(model.log_prob(samples[-1], beta))
    energy.append(ising.energy(samples[-1], pbc=True))
    free_energy.append(np.mean(((log_prob[-1]/beta)+energy[-1])/(model.L**2)))

# %%
mags2 = np.empty_like(betas)
Cv2 = np.empty_like(betas)

for i,sample in enumerate(samples):
    mags2[i] = np.mean(np.abs(np.mean(sample, axis=(1,2,3))))
    Cv2[i] = np.var(energy[i])

# %%
plt.plot(1./np.asarray(betas), mags1, label='L=24', color='red')
plt.plot(1./np.asarray(betas), mags3, label='L=48', color='green')
plt.plot(1./np.asarray(betas), mags2, label='L=96', color='blue')
plt.grid()
plt.xlabel('Temperature')
plt.ylabel('Magnetization')
plt.legend()
plt.savefig('BPnet_mags.png')
plt.show()

# %%
plt.plot(1./np.asarray(betas), Cv1/(24**2), label='L=24', color='red')
plt.plot(1./np.asarray(betas), Cv3/(48**2), label='L=48', color='green')
plt.plot(1./np.asarray(betas), Cv2/(96**2), label='L=96', color='blue')
plt.grid()
plt.xlabel('Temperature')
plt.ylabel('Specific heat')
plt.legend()
plt.savefig('BPnet_Cv.png')
plt.show()

# %%
beta = np.arange(0.3, 0.60001, 0.0125)
integral = integrator(beta)
F = -np.reciprocal(beta)*(math.log(2)/2 + integral*(1./(2*math.pi)))

# %%
#betas = np.asarray(betas)
integral = integrator(betas)
F = -np.reciprocal(betas)*(math.log(2)/2 + integral*(1./(2*math.pi)))
free_energy_arr = np.asarray(free_energy)
error2 = (free_energy_arr-F)

# %%
plt.plot(betas, F, color='blue', label='Exact solution')
plt.scatter(betas, free_energy, color='red', label='BPnet values')
plt.xlabel('Beta')
plt.ylabel('Free energy per particle')
plt.grid()
plt.legend()
plt.savefig('BPnet_free_ener.png')
plt.show()

# %%
plt.plot(betas, error, color='blue', label='L=36')
plt.plot(betas, error2, color='green', label='L=72')
plt.title('CondBPnet')
plt.xlabel('Beta')
plt.ylabel('Error in F')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Sampling times of SimplePCNN and BPnet

# %%
from time import time
from scipy import stats

# %%
lens = np.arange(24, 121, 12, dtype=int)
times = np.empty_like(lens, float)

for i,L in enumerate(lens):
    model = SimplePCNN(L, net_depth=3, net_width=16, kernel_size=5)
    model.load_weights('SimplePCNNwts/b_0.45')
    t0 = time()
    model.sample(200)
    times[i] = time() - t0

# %%
lens = np.arange(24, 121, 12, dtype=int)
times2 = np.empty_like(lens, float)

for i,L in enumerate(lens):
    model = BPnet(L, net_depth=3, net_width=16, kernel_size=5)
    model.load_weights('BPnetwts/b_0.45')
    t0 = time()
    model.sample(200)
    times2[i] = time() - t0

# %%
times
# Out:
# array([   7.4296546 ,   30.48092818,   86.66682982,  202.32232666,
#         405.40487814,  736.14312887, 1238.66184187, 1971.92775154,
#        3001.33109379])

# %%
times2
# Out:
# array([  4.87966657,  13.26693058,  32.37037158,  91.84282613,
#        131.94992805, 175.5694201 , 211.77747869, 249.13335085,
#        315.22556186])

# %%
plt.scatter(lens**2, times, color='red', label='SimplePCNN')
plt.scatter(lens**2, times2, color='green', label="BPnet")
plt.xlabel('Number of spins (N)')
plt.ylabel('Sampling time')
plt.legend()
plt.grid()
plt.savefig('Sample_timings.png')
plt.show()

# %%
import statsmodels.api as sm
from sklearn.preprocessing import PolynomialFeatures

# %%
X = np.expand_dims(lens**2, 1)
poly_ft = PolynomialFeatures(degree=2)
X2 = poly_ft.fit_transform(X)
Y = times
est = sm.OLS(Y, X2).fit()
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 4.678e+05
# Date:                Wed, 12 May 2021   Prob (F-statistic):           2.64e-16
# Time:                        18:27:04   Log-Likelihood:                -20.945
# No. Observations:                   9   AIC:                             47.89
# Df Residuals:                       6   BIC:                             48.48
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.7544      2.449      1.124      0.304      -3.239       8.748
# x1             0.0036      0.001      4.137      0.006       0.001       0.006
# x2           1.42e-05   5.79e-08    245.086      0.000    1.41e-05    1.43e-05
# ==============================================================================
# Omnibus:                        1.546   Durbin-Watson:                   1.464
# Prob(Omnibus):                  0.462   Jarque-Bera (JB):                0.781
# Skew:                          -0.266   Prob(JB):                        0.677
# Kurtosis:                       1.658   Cond. No.                     2.17e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.17e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /home/dinesh/miniconda3/envs/tf-cuda/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=9
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
y_pred = est.predict(X2)
plt.scatter(lens**2, times, color='red', label='Actual Times')
plt.plot(lens**2, y_pred, color='blue', label='Predicted values')
plt.legend()
plt.xlabel('Number of spins (N)')
plt.ylabel('Time (in seconds)')
plt.show()

# %%
X = np.expand_dims(lens**2, 1)
poly_ft = PolynomialFeatures(degree=2)
X2 = poly_ft.fit_transform(X)
Y = times2
est = sm.OLS(Y, X2).fit()
print(est.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                     379.4
# Date:                Wed, 12 May 2021   Prob (F-statistic):           4.83e-07
# Time:                        18:50:10   Log-Likelihood:                -32.748
# No. Observations:                   9   AIC:                             71.50
# Df Residuals:                       6   BIC:                             72.09
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -19.6295      9.091     -2.159      0.074     -41.874       2.615
# x1             0.0305      0.003      9.486      0.000       0.023       0.038
# x2         -5.388e-07   2.15e-07     -2.506      0.046   -1.06e-06   -1.28e-08
# ==============================================================================
# Omnibus:                        2.195   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.334   Jarque-Bera (JB):                1.148
# Skew:                          -0.575   Prob(JB):                        0.563
# Kurtosis:                       1.681   Cond. No.                     2.17e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.17e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /home/dinesh/miniconda3/envs/tf-cuda/lib/python3.8/site-packages/scipy/stats/stats.py:1603: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=9
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
y_pred = est.predict(X2)
plt.scatter(lens**2, times2, color='red', label='Actual Times')
plt.plot(lens**2, y_pred, color='blue', label='Predicted values')
plt.legend()
plt.xlabel('Number of spins (N)')
plt.ylabel('Time (in seconds)')
plt.show()
